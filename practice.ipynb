# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
    "https://en.wikipedia.org/wiki/Tata_Consultancy_Services",
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(id="mw-content-text")
    )
)

webdata = loader.load()

print("documents loaded:", len(webdata))

if webdata:
    text = webdata[0].page_content
    print(text[:2000])  # print first 2000 chars
else:
    print("No content was loaded")

sentences = [s.strip() for s in text.split(". ") if s.strip()]
for s in sentences[:10]:
    print(f"- {s}")
# Out:
# documents loaded: 1
#
# Indian multinational technology company
#
#
# Tata Consultancy Services LimitedTypePublicTraded asBSE: 532540NSE: TCSBSE SENSEX constituentNSE NIFTY 50 constituentISININE467B01029IndustryInformation technologyConsultingOutsourcingFounded1968; 58 years ago (1968)FounderJ. R. D. TataHeadquartersMumbai, Maharashtra, IndiaArea servedWorldwideKey peopleNatarajan Chandrasekaran(Chairman)K. Krithivasan(MD & CEO)Revenue ₹271,423 crore (US$28 billion)[1] (2026)Operating income ₹70,013 crore (US$7.3 billion) (2026)Net income ₹49,454 crore (US$5.2 billion) (2026)Total assets ₹182,372 crore (US$19 billion) (2026)Total equity ₹108,478 crore (US$11 billion) (2026)OwnerTata Sons (71.74%)[2]Number of employees584,519 (March 2026)[3]ParentTata GroupSubsidiariesTRDDCWebsitetcs.comFootnotesFinancials as of 31 March 2025[update].[4]
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
    "https://en.wikipedia.org/wiki/Tata_Consultancy_Services",
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(id="mw-content-text")
    )
)

webdata = loader.load()

print("documents loaded:", len(webdata))

if webdata:
    text = webdata[0].page_content
    print("✅ Content extracted\n")

    # Split into sentences and print as bullet points
    sentences = [s.strip() for s in text.split(". ") if s.strip()]
    for s in sentences[:10]:   # limit to first 10 sentences
        print(f"- {s}")
else:
    print("No content was loaded")
# Out:
# documents loaded: 1
# ✅ Content extracted
#
# - Indian multinational technology company
#
#
# Tata Consultancy Services LimitedTypePublicTraded asBSE: 532540NSE: TCSBSE SENSEX constituentNSE NIFTY 50 constituentISININE467B01029IndustryInformation technologyConsultingOutsourcingFounded1968; 58 years ago (1968)FounderJ
# - R
# - D
# - TataHeadquartersMumbai, Maharashtra, IndiaArea servedWorldwideKey peopleNatarajan Chandrasekaran(Chairman)K
# - Krithivasan(MD & CEO)Revenue ₹271,423 crore (US$28 billion)[1] (2026)Operating income ₹70,013 crore (US$7.3 billion) (2026)Net income ₹49,454 crore (US$5.2 billion) (2026)Total assets ₹182,372 crore (US$19 billion) (2026)Total equity ₹108,478 crore (US$11 billion) (2026)OwnerTata Sons (71.74%)[2]Number of employees584,519 (March 2026)[3]ParentTata GroupSubsidiariesTRDDCWebsitetcs.comFootnotesFinancials as of 31 March 2025[update].[4]
# ...
