# %%
#Data loading first step
from langchain_community.document_loaders import TextLoader
loader = TextLoader("cppData.txt", encoding="utf-8")
txtData = loader.load()
print(txtData[0])

# %%
#splitting data into documents 
from langchain_text_splitters import RecursiveCharacterTextSplitter
text#Splitter = RecursiveCharacterTextSplitter(chunk_size= 200, chunk_overlap=20)
finalDocuments = textSplitter.split_documents(txtData)
finalDocuments

# %%
# This face is embedding phase here we will convert the text data into vectors
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLm-L6-v2")

# %%
#vector store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db

# %%
query = input("Enter your question for C++: ")
docs = db.similarity_search(query)
for i in range(len(docs)):
    print(docs[i].page_content)
